# %% [markdown]
# # PokerRL Cloud Training (Google Colab)
#
# This notebook allows you to train the PokerRL agent using Google Colab's free GPU resources.
#
# ## 1. Setup Environment
# First, we'll clone the repository and install dependencies.

# %%
# Clone the repository (Replace with your actual repo URL if hosted on GitHub)
# !git clone https://github.com/YOUR_USERNAME/PokerRL_Vanilla.git
# %cd PokerRL_Vanilla

# Install dependencies
# !pip install torch numpy

# %% [markdown]
# ## 2. Run Training
# Now we can run the trainer. You can adjust the number of episodes and other parameters.

# %%
# !python3 -m src.training.trainer --episodes 5000 --batch_size 64 --save_path models/cloud_agent.pt

# %% [markdown]
# ## 3. Download the Trained Model
# After training, you can download the model back to your local machine.

# %%
from google.colab import files
files.download('models/cloud_agent.pt')
